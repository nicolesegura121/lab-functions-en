# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if type(a) == int: 
        if type(b) == int: 
            if a < b : 
                return b
            if a > b:
                return a
            if a == b: 
                return f"Numbers must be different"
        else:
            return f"Input must be integer"
    else:
        return f"Input must be integer"

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.215s
#
# OK

# %%
#Showing function with negative values
greater(-100,2)
# Out:
# 2

# %%
#Showing function when values are equal
greater(2,2)
# Out:
# 'Numbers must be different'

# %%
#Showing when values are not numbers
greater("a",100)
# Out:
# 'Input must be integer'

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
def greatest(list_of_things):  
           
    largest = list_of_things[0]

    for item in list_of_things: 
        if item > largest: 
            largest = item
    return largest

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.248s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(lst):
    total = 0

    for i in lst: 
        total+=i
    
    return total

# %%
lista = [0,1,2,3,4]
sum_all(lista)
# Out:
# 10

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.263s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(lst):
    value = 1
    for i in lst: 
        value*=i
    return value

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ..........
# ..........................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.222s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper = "*"):
    if oper =="*":
        return mult_all(arr)
    elif oper == "+":
        return sum_all(arr)

# %%
lista = [10,10,10]

oper_all(lista)
# Out:
# 1000

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# .........
# ...........................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.293s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    result=1
    for i in range(1, n+1):
        result*=i
    return result

# %%
#factorial formula
#n! = n * ( n - 1 ) *...*1

# This code defines a function called "factorial" which takes an input "n". The function uses a for loop to iterate through the range of numbers 
# from 1 to n+1. For each number in that range, it multiplies the current value of x by the number in the range. At the end of the loop, 
# the function returns the final value of x, which will be the factorial of the input number "n".

# The Factorial of a positive integer n is the product of all positive integers less than or equal to n. 
# For example, the factorial of 6 (written "6!") is 6 * 5 * 4 * 3 * 2 * 1 = 720.

# So this function takes an input of any positive integer, and returns the factorial of that number.

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.298s
#
# OK

# %%
#Recursive mode

def factorial2(n): 
    if n==0: 
        return 1
    elif n > 0 :
        result = n*factorial2(n-1)
        return result

# %%
# This will test your function 
test_factorial(factorial2)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.361s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
#To test for uniqueness, the item must appear only once

# %%
#Using built-in functions :(
def unique(lst_un):
    for item in lst_un:
        if lst_un.count(item)!=1: 
            lst_un.remove(item)
        return lst_un

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.245s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
    mode = 1
    for item in arr: 
        if arr.count(item) > mode: 
            mode = arr.count(item)
    return item

# %%
# This will test your function 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.311s
#
# OK

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
lista3 = [10,10,10]
lista3_avg = sum_all(lista3)/len(lista3)
lista3_avg
lista3_var = []
for i in lista3: 
    lista3_var.append(i-lista3_avg)
sum_all(lista3_var)
# Out:
# 0.0

# %%
def st_dev(list_sd):
    #single parameter
    x_avg = sum_all(list_sd)/len(list_sd)
    squared_x_var = []
    for x in list_sd: 
        squared_x_var.append((x-x_avg)**2)

    std = (sum_all(squared_x_var)/(len(list_sd)-1))**(1/2)
  
    return std

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.197s
#
# OK

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
import string
string.ascii_lowercase = set(string.ascii_lowercase)
type(string.ascii_lowercase)
# Out:
# set

# %%
def pangram(sentence):
    #Importing an alphabet
    import string
    string.ascii_lowercase = set(string.ascii_lowercase)
    #Simplifying the sentence if there is any uppercase
    sentence = sentence.lower()
    #Defining an empty set to collect all letters present in the sentence
    letters = set()

    for letter in sentence: 

        if letter in string.ascii_lowercase: 

            letters.add(letter)

    return string.ascii_lowercase.issubset(letters)

# %%
sentence2 = "The quick brown fox jumps over the lazy dog"
pangram(sentence2)
# Out:
# True

# %%
# This will test your function 
test_pangram(pangram)
# Out:
# ..............
# ................
# ----------------------------------------------------------------------
# Ran 30 tests in 0.077s
#
# OK

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
#I will generate a function that goes through all characters and stop until a comma is encountered
def sort_alpha(string):
    lst = []
    string_modified = ""

    for character in string:
        if character!=",":
            string_modified+=character
        else:
            lst.append(string_modified)
            string_modified=""
    
    lst.append(string_modified)
        
    lst.sort()
    strng = ",".join(lst)
    x = strng.replace(" ","")

    return x

# %%
sentence3 = "This, are, comma, separated, words"
sort_alpha(sentence3)
# Out:
# 'are,comma,separated,words,This'

# %%
# This will test your function 
test_alpha(sort_alpha)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.112s
#
# OK

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.

# %%
def check_pass(password):
        
    if len(password) < 8:
        return False
    else: 
        if not any([character.isupper() for character in password]):
            return False
        else: 

            if not any([character.islower() for character in password]):
                return False
            else: 
                if not any([character.isdigit() for character in password]):
                    return False
                else: 
                    if not any([not character.isalnum() for character in password]):
                        return False
                    else:
                        return True

# %%
# This will test your function 
test_pass(check_pass)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.118s
#
# OK
